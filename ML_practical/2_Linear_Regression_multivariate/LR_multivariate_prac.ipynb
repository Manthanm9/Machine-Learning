# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount= True)
# Out:
# Mounted at /content/gdrive/

# %%
df = pd.read_csv("/content/gdrive/My Drive/ML_practical/2_Linear_Regression_multivariate/realest.csv")
df.drop(df.tail(1).index, inplace = True)

# %%
df
# Out:
#      Price  Bedroom   Space  Room   Lot     Tax  Bathroom  Garage  Condition
# 0     53.0      2.0   967.0   5.0  39.0   652.0       1.5     0.0        0.0
# 1     55.0      2.0   815.0   5.0  33.0  1000.0       1.0     2.0        1.0
# 2     56.0      3.0   900.0   5.0  35.0   897.0       1.5     1.0        0.0
# 3     58.0      3.0  1007.0   6.0  24.0   964.0       1.5     2.0        0.0
# 4     64.0      3.0  1100.0   7.0  50.0  1099.0       1.5     1.5        0.0
# ..     ...      ...     ...   ...   ...     ...       ...     ...        ...
# 151   42.0      3.0   585.0   5.0  50.0   713.0       1.0     0.0        0.0
# 152   44.0      3.0   820.0   5.0  27.0     NaN       1.0     0.0        1.0
# 153   43.0      2.0   593.0   4.0  30.0   465.0       2.0     1.0        0.0
# 154   53.0      3.0   716.0   6.0  30.0   585.0       1.0     2.0        1.0
# 155   62.0      4.0   951.0   7.0  30.0   895.0       2.0     1.0        0.0
#
# [156 rows x 9 columns]

# %%
import matplotlib.pyplot as plt

# Assuming your data is stored in a pandas DataFrame called 'df'
x = df[['Space', 'Room', 'Bedroom']]
y = df['Price']

# Create the scatter plot
plt.scatter(x['Space'], y, label='Space')
plt.scatter(x['Room'], y, label='Room')
plt.scatter(x['Bedroom'], y, label='Bedroom')

# Set the labels and title
plt.xlabel('Space, Room, Bedroom')
plt.ylabel('Price')
plt.title('Scatter Plot: Space, Room, and Bedroom vs Price')

# Add a legend
plt.legend()

# Display the plot
plt.show()

# %%
df.describe()
# Out:
#             Price     Bedroom        Space        Room         Lot  \
# count  156.000000  156.000000   146.000000  156.000000  146.000000
# mean    56.474359    3.166667  1097.246575    6.500000   32.808219
# std     12.875307    1.348037   462.540698    1.675247    8.457859
# min     32.000000    1.000000   539.000000    4.000000   24.000000
# 25%     46.000000    2.000000   805.250000    5.000000   25.000000
# 50%     55.000000    3.000000   965.500000    6.000000   30.000000
# 75%     65.000000    4.000000  1220.500000    7.000000   37.000000
# max     90.000000    8.000000  2295.000000   12.000000   50.000000
#
#                Tax    Bathroom      Garage   Condition
# count   147.000000  156.000000  156.000000  156.000000
# mean    911.707483    1.480769    0.846154    0.230769
# std     443.263430    0.529408    0.808454    0.422682
# min     418.000000    1.000000    0.000000    0.000000
# 25%     652.500000    1.000000    0.000000    0.000000
# ...

# %%
df['Space'].median()
# Out:
# 965.5

# %%
df['Space'].fillna( df['Space'].mean(), inplace = True)

# %%
x = df[['Space', 'Room', 'Bedroom']]
x
# Out:
#       Space  Room  Bedroom
# 0     967.0   5.0      2.0
# 1     815.0   5.0      2.0
# 2     900.0   5.0      3.0
# 3    1007.0   6.0      3.0
# 4    1100.0   7.0      3.0
# ..      ...   ...      ...
# 151   585.0   5.0      3.0
# 152   820.0   5.0      3.0
# 153   593.0   4.0      2.0
# 154   716.0   6.0      3.0
# 155   951.0   7.0      4.0
#
# [156 rows x 3 columns]

# %%
y  = df[['Price']]
y
# Out:
#      Price
# 0     53.0
# 1     55.0
# 2     56.0
# 3     58.0
# 4     64.0
# ..     ...
# 151   42.0
# 152   44.0
# 153   43.0
# 154   53.0
# 155   62.0
#
# [156 rows x 1 columns]

# %%
from sklearn import linear_model

reg = linear_model.LinearRegression()

reg.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# Find price of home with **Mean** sqr fitarea, **Mean** Rooms,**Mean** bedrooms
#
#
# ---
#
#
#
# ---

# %%
reg.predict([[1097.246575, 6.500000,	3.166667]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[56.47435748]])

# %%
reg.predict([[820, 5, 3]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[46.44771483]])
