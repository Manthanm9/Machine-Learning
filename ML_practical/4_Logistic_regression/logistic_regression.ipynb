# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount= True)
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv("/content/gdrive/My Drive/ML_practical/Linear_Regression_multivariate/insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   28                 0
# 1   27                 0
# 2   29                 0
# 3   49                 1
# 4   55                 1

# %%
plt.scatter(df.age, df.bought_insurance, marker = '*', color = 'orange')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, train_size = 0.8)
print(len(x_train), len(x_test))
print(len(y_train), len(y_test))
# Out:
# 24 6
# 24 6

# %%
x_test
# Out:
#     age
# 0    28
# 22   55
# 12   45
# 14   54
# 21   56
# 20   46

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
x_test
# Out:
#     age
# 0    28
# 22   55
# 12   45
# 14   54
# 21   56
# 20   46

# %%
 y_pred = model.predict(x_test)
 y_pred
# Out:
# array([0, 1, 1, 1, 1, 1])

# %%
model.predict_proba(x_test)
# Out:
# array([[0.77987915, 0.22012085],
#        [0.10489137, 0.89510863],
#        [0.29288073, 0.70711927],
#        [0.11735068, 0.88264932],
#        [0.09361458, 0.90638542],
#        [0.26743167, 0.73256833]])

# %%
model.score(x_test, y_test)
# Out:
# 0.8333333333333334

# %%
model.coef_
# Out:
# array([[0.1262586]])

# %%
model.intercept_
# Out:
# array([-4.80020303])

# %%
import math
def sigmoid(x):
  return 1/ (1 + math.exp(-x))

# %%
def prediction_funct (age):
  z = 0.042 * age - 0.13
  y = sigmoid(z)
  return y

# %%
age = 35
prediction_funct(age)
# Out:
# 0.7924899414403644

# %%
age  = 43
prediction_funct(age)
# Out:
# 0.8423741383953062
